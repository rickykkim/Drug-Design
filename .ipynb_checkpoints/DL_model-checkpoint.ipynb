# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# TODO: Define columns used as multivariate time-series features
TS_FEATURE_COLS = [
    "tbl_speed",
    "fom",
    "main_comp",
    "tbl_fill",
    "SREL",
    "pre_comp",
    "produced",
    "waste",
    "cyl_main",
    "cyl_pre",
    "stiffness",
    "ejection"
]


TARGET_COLS = ["total_waste", "Total impurities"]

# Load process-level targets
print("Loading Process.csv (targets)...")
process = pd.read_csv("data/Process.csv", sep=";")      

# Keep only the necessary columns
cols = ["batch", "code"] + TARGET_COLS
process = process[cols]

# Drop batches that do not have valid target values
process = process.dropna(subset=TARGET_COLS).reset_index(drop=True)
print(f"Process targets shape: {process.shape}")

# Normalize target values
target_scaler = StandardScaler()
process[TARGET_COLS] = target_scaler.fit_transform(process[TARGET_COLS])
print("Normalized target variables.")

# Load and concatenate all time-series CSV files
print("\nLoading time-series CSV files...")
dfs = []
for i in range(1, 26):
    df = pd.read_csv(f"data/Time-Series/{i}.csv", sep=";")
    dfs.append(df)
    
ts = pd.concat(dfs, ignore_index=True)
print(f"Time-series shape: {ts.shape}")

# Normalize time-series feature columns
ts_scaler = StandardScaler()
ts[TS_FEATURE_COLS] = ts_scaler.fit_transform(ts[TS_FEATURE_COLS])
print("Normalized TS features:", TS_FEATURE_COLS)
# Out:
# Loading Process.csv (targets)...
# Process targets shape: (987, 4)
# Normalized target variables.
#
# Loading time-series CSV files...
# Time-series shape: (4720208, 16)
# Normalized TS features: ['tbl_speed', 'fom', 'main_comp', 'tbl_fill', 'SREL', 'pre_comp', 'produced', 'waste', 'cyl_main', 'cyl_pre', 'stiffness', 'ejection']

# %% [markdown]
# # Build Sequences

# %%
# Keep only time-series data whose batch IDs appear in the process targets
valid_batches = set(process["batch"].unique())
ts = ts[ts["batch"].isin(valid_batches)].copy()

# Fill missing feature values within each batch
def fill_group(g):
    g = g.copy()
    g = g.ffill()         # forward fill missing values
    g = g.bfill()         # backward fill any remaining gaps
    g = g.fillna(0.0)     # fill any remaining NaNs with 0.0
    return g

# Apply the filling function to each batch
ts[TS_FEATURE_COLS] = ts.groupby("batch")[TS_FEATURE_COLS].transform(fill_group)

# Compute the number of time steps for each batch
batch_lengths = ts.groupby("batch").size()

# Get the distribution of sequence lengths and its 95th percentile
p95 = np.percentile(batch_lengths.to_numpy(), 95)

# Define the maximum sequence length to control memory usage
max_seq_len = int(min(p95, 5000))
print(f"Maximum sequence length: {max_seq_len}")

# Sort batch IDs for reproducible ordering
batch_ids = sorted(batch_lengths.index)

X_list, y_list = [], []
for b in batch_ids:
    # Extract feature matrix (T, C) for each batch
    g = ts[ts["batch"] == b]
    seq = g[TS_FEATURE_COLS].values.astype(np.float32)
    
    # Truncate or pad to maximum sequence length
    if seq.shape[0] >= max_seq_len:
        seq = seq[:max_seq_len, :]
    else:
        pad_len = max_seq_len - seq.shape[0]
        pad = np.zeros((pad_len, seq.shape[1]), dtype=np.float32)
        seq = np.vstack([seq, pad])
        
    # Align each batch with its target values
    row = process.loc[process["batch"] == b, TARGET_COLS]
    y = row.iloc[0].values.astype(np.float32)
    
    X_list.append(seq)
    y_list.append(y)

X = np.stack(X_list, axis=0)    # (num_batches, T, C)
y = np.stack(y_list, axis=0)    # (num_batches, 2)

print(f"Built sequences with X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Maximum sequence length: 5000
# Built sequences with X shape: (987, 5000, 12), y shape: (987, 2)

# %% [markdown]
# # Train/Validation Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

num_batches, T, C = X.shape

# Scale input features per-channel over all timesteps and batches
X_reshaped = X.reshape(-1, C)  # Flatten: (num_batches * T, C)

x_scaler = StandardScaler()
X_scaled_reshaped = x_scaler.fit_transform(X_reshaped)

# Restore original structure: (num_batches, T, C)
X_scaled = X_scaled_reshaped.reshape(num_batches, T, C).astype(np.float32)

# Scale target variables over the 2D target array
y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y).astype(np.float32)

# Split batches into training and validation sets
X_t, X_v, y_t, y_v = train_test_split(
    X_scaled, y_scaled, test_size=0.2, random_state=42
)

print(f"X_train shape: {X_t.shape}, y_train shape: {y_t.shape}")
print(f"X_val shape: {X_v.shape}, y_val shape: {y_v.shape}")
# Out:
# X_train shape: (789, 5000, 12), y_train shape: (789, 2)
# X_val shape: (198, 5000, 12), y_val shape: (198, 2)

# %% [markdown]
# # Build and Train CNN

# %%
import importlib
import utils.cnn as cnn
importlib.reload(cnn)

from utils.cnn import CNN_trainer

# Build and train the model
cnn_trainer = CNN_trainer(
    X_t, y_t, 
    X_v, y_v,
    epochs=100,         # Number of epochs
    batch_size=128,     # Batch size
    lr=1e-3,            # Learning rate
    l2=1e-5,            # L2 regularization coefficient
)
cnn_trainer.run()
# Out:
# Training Epoch 1/100
# 7/7 - loss: 1.0128 - MAE: 0.8092 - val_loss: 0.8732 - val_MAE: 0.7434
# Learning rate: 0.001000
# Validation MAE improved to 0.7434
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 2/100
# 7/7 - loss: 0.8335 - MAE: 0.7038 - val_loss: 0.8045 - val_MAE: 0.7128
# Learning rate: 0.001000
# Validation MAE improved to 0.7128
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 3/100
# 7/7 - loss: 0.7656 - MAE: 0.6678 - val_loss: 0.7521 - val_MAE: 0.6918
# Learning rate: 0.000999
# Validation MAE improved to 0.6918
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 4/100
# 7/7 - loss: 0.7500 - MAE: 0.6347 - val_loss: 0.7250 - val_MAE: 0.6710
# Learning rate: 0.000998
# Validation MAE improved to 0.6710
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 5/100
# 7/7 - loss: 0.6565 - MAE: 0.5937 - val_loss: 0.7126 - val_MAE: 0.6644
# Learning rate: 0.000996
# Validation MAE improved to 0.6644
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 6/100
# 7/7 - loss: 0.6375 - MAE: 0.5778 - val_loss: 0.6956 - val_MAE: 0.6543
# Learning rate: 0.000994
# Validation MAE improved to 0.6543
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 7/100
# 7/7 - loss: 0.6374 - MAE: 0.5553 - val_loss: 0.6825 - val_MAE: 0.6374
# Learning rate: 0.000991
# Validation MAE improved to 0.6374
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 8/100
# 7/7 - loss: 0.6141 - MAE: 0.5461 - val_loss: 0.6723 - val_MAE: 0.6299
# Learning rate: 0.000988
# Validation MAE improved to 0.6299
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 9/100
# 7/7 - loss: 0.6941 - MAE: 0.5319 - val_loss: 0.6672 - val_MAE: 0.6158
# Learning rate: 0.000984
# Validation MAE improved to 0.6158
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 10/100
# 7/7 - loss: 0.5264 - MAE: 0.5139 - val_loss: 0.6760 - val_MAE: 0.6216
# Learning rate: 0.000980
# No improvement (patience: 1/5)
#
# Training Epoch 11/100
# 7/7 - loss: 0.5468 - MAE: 0.5183 - val_loss: 0.6322 - val_MAE: 0.5999
# Learning rate: 0.000975
# Validation MAE improved to 0.5999
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 12/100
# 7/7 - loss: 0.5584 - MAE: 0.4941 - val_loss: 0.6089 - val_MAE: 0.5776
# Learning rate: 0.000970
# Validation MAE improved to 0.5776
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 13/100
# 7/7 - loss: 0.5138 - MAE: 0.5024 - val_loss: 0.6050 - val_MAE: 0.5617
# Learning rate: 0.000964
# Validation MAE improved to 0.5617
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 14/100
# 7/7 - loss: 0.5921 - MAE: 0.4901 - val_loss: 0.6078 - val_MAE: 0.5605
# Learning rate: 0.000958
# Validation MAE improved to 0.5605
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 15/100
# 7/7 - loss: 0.4705 - MAE: 0.4802 - val_loss: 0.6094 - val_MAE: 0.5562
# Learning rate: 0.000951
# Validation MAE improved to 0.5562
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 16/100
# 7/7 - loss: 0.4926 - MAE: 0.4902 - val_loss: 0.6143 - val_MAE: 0.5643
# Learning rate: 0.000944
# No improvement (patience: 1/5)
#
# Training Epoch 17/100
# 7/7 - loss: 0.4923 - MAE: 0.4731 - val_loss: 0.6026 - val_MAE: 0.5493
# Learning rate: 0.000937
# Validation MAE improved to 0.5493
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 18/100
# 7/7 - loss: 0.5141 - MAE: 0.4607 - val_loss: 0.5932 - val_MAE: 0.5313
# Learning rate: 0.000929
# Validation MAE improved to 0.5313
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 19/100
# 7/7 - loss: 0.4435 - MAE: 0.4540 - val_loss: 0.5464 - val_MAE: 0.5051
# Learning rate: 0.000921
# Validation MAE improved to 0.5051
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 20/100
# 7/7 - loss: 0.4336 - MAE: 0.4497 - val_loss: 0.5453 - val_MAE: 0.5099
# Learning rate: 0.000912
# No improvement (patience: 1/5)
#
# Training Epoch 21/100
# 7/7 - loss: 0.4295 - MAE: 0.4467 - val_loss: 0.5487 - val_MAE: 0.5196
# Learning rate: 0.000903
# No improvement (patience: 2/5)
#
# Training Epoch 22/100
# 7/7 - loss: 0.4354 - MAE: 0.4474 - val_loss: 0.5428 - val_MAE: 0.5050
# Learning rate: 0.000893
# Validation MAE improved to 0.5050
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 23/100
# 7/7 - loss: 0.3730 - MAE: 0.4258 - val_loss: 0.5195 - val_MAE: 0.4889
# Learning rate: 0.000883
# Validation MAE improved to 0.4889
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 24/100
# 7/7 - loss: 0.3704 - MAE: 0.4274 - val_loss: 0.5386 - val_MAE: 0.4959
# Learning rate: 0.000873
# No improvement (patience: 1/5)
#
# Training Epoch 25/100
# 7/7 - loss: 0.3611 - MAE: 0.4330 - val_loss: 0.5527 - val_MAE: 0.4915
# Learning rate: 0.000862
# No improvement (patience: 2/5)
#
# Training Epoch 26/100
# 7/7 - loss: 0.3325 - MAE: 0.4180 - val_loss: 0.5124 - val_MAE: 0.4733
# Learning rate: 0.000851
# Validation MAE improved to 0.4733
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 27/100
# 7/7 - loss: 0.3782 - MAE: 0.4275 - val_loss: 0.5062 - val_MAE: 0.4629
# Learning rate: 0.000839
# Validation MAE improved to 0.4629
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 28/100
# 7/7 - loss: 0.3495 - MAE: 0.4075 - val_loss: 0.5026 - val_MAE: 0.4599
# Learning rate: 0.000827
# Validation MAE improved to 0.4599
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 29/100
# 7/7 - loss: 0.3539 - MAE: 0.4147 - val_loss: 0.4836 - val_MAE: 0.4519
# Learning rate: 0.000815
# Validation MAE improved to 0.4519
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 30/100
# 7/7 - loss: 0.3802 - MAE: 0.4229 - val_loss: 0.4934 - val_MAE: 0.4499
# Learning rate: 0.000803
# Validation MAE improved to 0.4499
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 31/100
# 7/7 - loss: 0.3190 - MAE: 0.4036 - val_loss: 0.4991 - val_MAE: 0.4512
# Learning rate: 0.000790
# No improvement (patience: 1/5)
#
# Training Epoch 32/100
# 7/7 - loss: 0.3313 - MAE: 0.3988 - val_loss: 0.4763 - val_MAE: 0.4325
# Learning rate: 0.000777
# Validation MAE improved to 0.4325
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 33/100
# 7/7 - loss: 0.3251 - MAE: 0.4013 - val_loss: 0.4612 - val_MAE: 0.4298
# Learning rate: 0.000764
# Validation MAE improved to 0.4298
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 34/100
# 7/7 - loss: 0.4096 - MAE: 0.3881 - val_loss: 0.4680 - val_MAE: 0.4302
# Learning rate: 0.000750
# No improvement (patience: 1/5)
#
# Training Epoch 35/100
# 7/7 - loss: 0.3385 - MAE: 0.4000 - val_loss: 0.5381 - val_MAE: 0.4402
# Learning rate: 0.000736
# No improvement (patience: 2/5)
#
# Training Epoch 36/100
# 7/7 - loss: 0.3554 - MAE: 0.4006 - val_loss: 0.4611 - val_MAE: 0.4273
# Learning rate: 0.000722
# Validation MAE improved to 0.4273
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 37/100
# 7/7 - loss: 0.3234 - MAE: 0.3915 - val_loss: 0.4724 - val_MAE: 0.4240
# Learning rate: 0.000708
# Validation MAE improved to 0.4240
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 38/100
# 7/7 - loss: 0.3003 - MAE: 0.3898 - val_loss: 0.4973 - val_MAE: 0.4256
# Learning rate: 0.000693
# No improvement (patience: 1/5)
#
# Training Epoch 39/100
# 7/7 - loss: 0.3434 - MAE: 0.3953 - val_loss: 0.4583 - val_MAE: 0.4129
# Learning rate: 0.000678
# Validation MAE improved to 0.4129
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 40/100
# 7/7 - loss: 0.3177 - MAE: 0.3940 - val_loss: 0.5055 - val_MAE: 0.4339
# Learning rate: 0.000664
# No improvement (patience: 1/5)
#
# Training Epoch 41/100
# 7/7 - loss: 0.3227 - MAE: 0.3804 - val_loss: 0.4715 - val_MAE: 0.4135
# Learning rate: 0.000648
# No improvement (patience: 2/5)
#
# Training Epoch 42/100
# 7/7 - loss: 0.2925 - MAE: 0.3801 - val_loss: 0.4625 - val_MAE: 0.4043
# Learning rate: 0.000633
# Validation MAE improved to 0.4043
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 43/100
# 7/7 - loss: 0.3244 - MAE: 0.3826 - val_loss: 0.4930 - val_MAE: 0.4149
# Learning rate: 0.000618
# No improvement (patience: 1/5)
#
# Training Epoch 44/100
# 7/7 - loss: 0.3091 - MAE: 0.3763 - val_loss: 0.5070 - val_MAE: 0.4276
# Learning rate: 0.000602
# No improvement (patience: 2/5)
#
# Training Epoch 45/100
# 7/7 - loss: 0.3523 - MAE: 0.3740 - val_loss: 0.4116 - val_MAE: 0.4012
# Learning rate: 0.000587
# Validation MAE improved to 0.4012
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 46/100
# 7/7 - loss: 0.2991 - MAE: 0.3771 - val_loss: 0.4282 - val_MAE: 0.3961
# Learning rate: 0.000571
# Validation MAE improved to 0.3961
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 47/100
# 7/7 - loss: 0.2731 - MAE: 0.3670 - val_loss: 0.4933 - val_MAE: 0.4115
# Learning rate: 0.000555
# No improvement (patience: 1/5)
#
# Training Epoch 48/100
# 7/7 - loss: 0.3328 - MAE: 0.3818 - val_loss: 0.4743 - val_MAE: 0.4047
# Learning rate: 0.000540
# No improvement (patience: 2/5)
#
# Training Epoch 49/100
# 7/7 - loss: 0.2779 - MAE: 0.3598 - val_loss: 0.4426 - val_MAE: 0.4010
# Learning rate: 0.000524
# No improvement (patience: 3/5)
#
# Training Epoch 50/100
# 7/7 - loss: 0.3181 - MAE: 0.3715 - val_loss: 0.4401 - val_MAE: 0.4042
# Learning rate: 0.000508
# No improvement (patience: 4/5)
#
# Training Epoch 51/100
# 7/7 - loss: 0.2737 - MAE: 0.3619 - val_loss: 0.4444 - val_MAE: 0.3950
# Learning rate: 0.000492
# Validation MAE improved to 0.3950
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 52/100
# 7/7 - loss: 0.2773 - MAE: 0.3647 - val_loss: 0.4502 - val_MAE: 0.3863
# Learning rate: 0.000476
# Validation MAE improved to 0.3863
# Saved best model weights to 'best_model_weights.h5'
#
# Training Epoch 53/100
# 7/7 - loss: 0.3435 - MAE: 0.3707 - val_loss: 0.4184 - val_MAE: 0.3906
# Learning rate: 0.000460
# No improvement (patience: 1/5)
#
# Training Epoch 54/100
# 7/7 - loss: 0.2818 - MAE: 0.3514 - val_loss: 0.4320 - val_MAE: 0.4033
# Learning rate: 0.000445
# No improvement (patience: 2/5)
#
# Training Epoch 55/100
# 7/7 - loss: 0.2622 - MAE: 0.3558 - val_loss: 0.4797 - val_MAE: 0.4065
# Learning rate: 0.000429
# No improvement (patience: 3/5)
#
# Training Epoch 56/100
# 7/7 - loss: 0.3108 - MAE: 0.3724 - val_loss: 0.4540 - val_MAE: 0.3964
# Learning rate: 0.000413
# No improvement (patience: 4/5)
#
# Training Epoch 57/100
# 7/7 - loss: 0.2592 - MAE: 0.3445 - val_loss: 0.5033 - val_MAE: 0.4097
# Learning rate: 0.000398
# No improvement (patience: 5/5)
# Early stopping triggered
# Loaded best model weights from 'best_model_weights.h5'
#
# CNN training complete. Best validation MAE: 0.3863)

# %% [markdown]
# # Build and Train LSTM

# %%
import importlib
import utils.lstm as lstm
importlib.reload(lstm)

from utils.lstm import LSTM_trainer

lstm_trainer = LSTM_trainer(
    X_t, y_t, 
    X_v, y_v, 
    epochs=100,          # Number of epochs
    batch_size=128,      # Batch size
    lr=1e-3,             # Learning rate
    l2=1e-5,             # L2 regularization coefficient
)
lstm_trainer.run()
# Out:
# Training Epoch 1/100
# 7/7 - loss: 0.9934 - MAE: 0.7622 - val_loss: 0.8736 - val_MAE: 0.7312
# Learning rate: 0.001000
# Validation MAE improved to 0.7312
# Updated the best LSTM model
#
# Training Epoch 2/100
# 7/7 - loss: 0.9189 - MAE: 0.7226 - val_loss: 0.8222 - val_MAE: 0.6991
# Learning rate: 0.001000
# Validation MAE improved to 0.6991
# Updated the best LSTM model
#
# Training Epoch 3/100
# 7/7 - loss: 0.8947 - MAE: 0.7042 - val_loss: 0.7742 - val_MAE: 0.6826
# Learning rate: 0.000999
# Validation MAE improved to 0.6826
# Updated the best LSTM model
#
# Training Epoch 4/100
# 7/7 - loss: 0.8384 - MAE: 0.6833 - val_loss: 0.7483 - val_MAE: 0.6628
# Learning rate: 0.000998
# Validation MAE improved to 0.6628
# Updated the best LSTM model
#
# Training Epoch 5/100
# 7/7 - loss: 0.7789 - MAE: 0.6648 - val_loss: 0.7328 - val_MAE: 0.6515
# Learning rate: 0.000996
# Validation MAE improved to 0.6515
# Updated the best LSTM model
#
# Training Epoch 6/100
# 7/7 - loss: 0.7782 - MAE: 0.6529 - val_loss: 0.7118 - val_MAE: 0.6334
# Learning rate: 0.000994
# Validation MAE improved to 0.6334
# Updated the best LSTM model
#
# Training Epoch 7/100
# 7/7 - loss: 0.7062 - MAE: 0.6474 - val_loss: 0.7461 - val_MAE: 0.6295
# Learning rate: 0.000991
# Validation MAE improved to 0.6295
# Updated the best LSTM model
#
# Training Epoch 8/100
# 7/7 - loss: 0.6828 - MAE: 0.6171 - val_loss: 0.7179 - val_MAE: 0.6063
# Learning rate: 0.000988
# Validation MAE improved to 0.6063
# Updated the best LSTM model
#
# Training Epoch 9/100
# 7/7 - loss: 0.6779 - MAE: 0.5935 - val_loss: 0.7430 - val_MAE: 0.6257
# Learning rate: 0.000984
# No improvement (patience: 1/5)
#
# Training Epoch 10/100
# 7/7 - loss: 0.6614 - MAE: 0.6156 - val_loss: 0.7882 - val_MAE: 0.6069
# Learning rate: 0.000980
# No improvement (patience: 2/5)
#
# Training Epoch 11/100
# 7/7 - loss: 0.6332 - MAE: 0.5767 - val_loss: 0.7464 - val_MAE: 0.6072
# Learning rate: 0.000975
# No improvement (patience: 3/5)
#
# Training Epoch 12/100
# 7/7 - loss: 0.6221 - MAE: 0.5839 - val_loss: 0.8037 - val_MAE: 0.6291
# Learning rate: 0.000970
# No improvement (patience: 4/5)
#
# Training Epoch 13/100
# 7/7 - loss: 0.5850 - MAE: 0.5624 - val_loss: 0.8633 - val_MAE: 0.6165
# Learning rate: 0.000964
# No improvement (patience: 5/5)
# Early stopping triggered
#
# LSTM training complete (Best validation MAE: 0.6063)

# %% [markdown]
# # Build and Train CNN + LSTM

# %%
import importlib
import utils.cnn_lstm as cnn_lstm
importlib.reload(cnn_lstm)

from utils.cnn_lstm import CNN_LSTM_trainer

cnn_lstm_trainer = CNN_LSTM_trainer(
    X_t, y_t, 
    X_v, y_v, 
    epochs=100,          # Number of epochs
    batch_size=128,      # Batch size
    lr=1e-3,             # Learning rate
    l2=1e-5,             # L2 regularization coefficient
)
cnn_lstm_trainer.run()
# Out:
# Training Epoch 1/100
# 7/7 - loss: 0.9544 - MAE: 0.7385
#  - val_loss: 0.8817 - val_MAE: 0.7445
# Learning rate: 0.001000
# Validation MAE improved to 0.7445
# Updated the best CNN+LSTM model
#
# Training Epoch 2/100
# 7/7 - loss: 0.8956 - MAE: 0.7129
#  - val_loss: 0.8471 - val_MAE: 0.7311
# Learning rate: 0.001000
# Validation MAE improved to 0.7311
# Updated the best CNN+LSTM model
#
# Training Epoch 3/100
# 7/7 - loss: 0.8727 - MAE: 0.6984
#  - val_loss: 0.8318 - val_MAE: 0.7288
# Learning rate: 0.000999
# Validation MAE improved to 0.7288
# Updated the best CNN+LSTM model
#
# Training Epoch 4/100
# 7/7 - loss: 0.8097 - MAE: 0.6933
#  - val_loss: 0.8123 - val_MAE: 0.7185
# Learning rate: 0.000998
# Validation MAE improved to 0.7185
# Updated the best CNN+LSTM model
#
# Training Epoch 5/100
# 7/7 - loss: 0.8476 - MAE: 0.6848
#  - val_loss: 0.8038 - val_MAE: 0.7057
# Learning rate: 0.000996
# Validation MAE improved to 0.7057
# Updated the best CNN+LSTM model
#
# Training Epoch 6/100
# 7/7 - loss: 0.7967 - MAE: 0.6824
#  - val_loss: 0.8036 - val_MAE: 0.7062
# Learning rate: 0.000994
# No improvement (patience: 1/5)
#
# Training Epoch 7/100
# 7/7 - loss: 0.7889 - MAE: 0.6778
#  - val_loss: 0.8009 - val_MAE: 0.6988
# Learning rate: 0.000991
# Validation MAE improved to 0.6988
# Updated the best CNN+LSTM model
#
# Training Epoch 8/100
# 7/7 - loss: 0.7630 - MAE: 0.6688
#  - val_loss: 0.8159 - val_MAE: 0.7025
# Learning rate: 0.000988
# No improvement (patience: 1/5)
#
# Training Epoch 9/100
# 7/7 - loss: 0.7511 - MAE: 0.6714
#  - val_loss: 0.8527 - val_MAE: 0.7037
# Learning rate: 0.000984
# No improvement (patience: 2/5)
#
# Training Epoch 10/100
# 7/7 - loss: 0.7676 - MAE: 0.6646
#  - val_loss: 0.8551 - val_MAE: 0.6955
# Learning rate: 0.000980
# Validation MAE improved to 0.6955
# Updated the best CNN+LSTM model
#
# Training Epoch 11/100
# 7/7 - loss: 0.7467 - MAE: 0.6618
#  - val_loss: 0.8680 - val_MAE: 0.7094
# Learning rate: 0.000975
# No improvement (patience: 1/5)
#
# Training Epoch 12/100
# 7/7 - loss: 0.7157 - MAE: 0.6607
#  - val_loss: 0.8547 - val_MAE: 0.7027
# Learning rate: 0.000970
# No improvement (patience: 2/5)
#
# Training Epoch 13/100
# 7/7 - loss: 0.7376 - MAE: 0.6563
#  - val_loss: 0.8745 - val_MAE: 0.7056
# Learning rate: 0.000964
# No improvement (patience: 3/5)
#
# Training Epoch 14/100
# 7/7 - loss: 0.7225 - MAE: 0.6573
#  - val_loss: 0.8548 - val_MAE: 0.7038
# Learning rate: 0.000958
# No improvement (patience: 4/5)
#
# Training Epoch 15/100
# 7/7 - loss: 0.7024 - MAE: 0.6443
#  - val_loss: 0.8402 - val_MAE: 0.6966
# Learning rate: 0.000951
# No improvement (patience: 5/5)
# Early stopping triggered
#
# CNN+LSTM training complete. Best validation MAE: 0.6955)

# %% [markdown]
# # Training & Validation MAE Curves

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# CNN
plt.plot(cnn_trainer.history["loss"], label="CNN Train MAE", color="blue")
plt.plot(cnn_trainer.history["val_loss"], label="CNN Val MAE", color="blue", linestyle="--")

# LSTM
plt.plot(lstm_trainer.history["loss"], label="LSTM Train MAE", color="green")
plt.plot(lstm_trainer.history["val_loss"], label="LSTM Val MAE", color="green", linestyle="--")

# CNN+LSTM
plt.plot(cnn_lstm_trainer.history["loss"], label="Hybrid Train MAE", color="red")
plt.plot(cnn_lstm_trainer.history["val_loss"], label="Hybrid Val MAE", color="red", linestyle="--")

plt.title("Training and Validation MAE Across Models")
plt.xlabel("Epoch")
plt.ylabel("MAE Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Final Validation MAE

# %%
final_val_mae = [
    cnn_trainer.history["val_loss"][-1],
    lstm_trainer.history["val_loss"][-1],
    cnn_lstm_trainer.history["val_loss"][-1]
]

labels = ["CNN", "LSTM", "CNN+LSTM"]

plt.figure(figsize=(7,5))
plt.bar(labels, final_val_mae, color=["blue", "green", "red"])
plt.ylabel("Validation MAE")
plt.title("Final Validation MAE Comparison")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# # Predicted vs Actual Plot

# %%
# Generate predictions
y_pred_cnn = cnn_trainer.model.predict(X_v)
y_pred_lstm = lstm_trainer.model.predict(X_v)
y_pred_hybrid = cnn_lstm_trainer.model.predict(X_v)

plt.figure(figsize=(8, 6))

# Only plot first output target: total_waste
true_vals = y_v[:, 0]

plt.scatter(true_vals, y_pred_cnn[:, 0], alpha=0.4, label="CNN", color="blue")
plt.scatter(true_vals, y_pred_lstm[:, 0], alpha=0.4, label="LSTM", color="green")
plt.scatter(true_vals, y_pred_hybrid[:, 0], alpha=0.4, label="CNN+LSTM", color="red")

lims = [true_vals.min(), true_vals.max()]
plt.plot(lims, lims, 'k--', label="Ideal Line")

plt.xlabel("True Values (scaled)")
plt.ylabel("Predicted Values (scaled)")
plt.title("Predicted vs True (Target: total_waste)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Residual Error Distribution

# %%
err_cnn = np.abs(y_pred_cnn[:, 0] - y_v[:, 0])
err_lstm = np.abs(y_pred_lstm[:, 0] - y_v[:, 0])
err_hybrid = np.abs(y_pred_hybrid[:, 0] - y_v[:, 0])

plt.figure(figsize=(10,6))
plt.hist(err_cnn, bins=40, alpha=0.5, label="CNN", color="blue")
plt.hist(err_lstm, bins=40, alpha=0.5, label="LSTM", color="green")
plt.hist(err_hybrid, bins=40, alpha=0.5, label="Hybrid", color="red")

plt.title("Residual Error Distribution | Absolute Error (Target: total_waste)")
plt.xlabel("Absolute Error")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Time-Series Prediction

# %%
idx = 5  # pick any validation batch

true_value = y_v[idx, 0]
p_cnn = y_pred_cnn[idx, 0]
p_lstm = y_pred_lstm[idx, 0]
p_hybrid = y_pred_hybrid[idx, 0]

plt.figure(figsize=(8,5))
plt.bar(["True", "CNN", "LSTM", "CNN+LSTM"], 
        [true_value, p_cnn, p_lstm, p_hybrid],
        color=["black", "blue", "green", "red"])

plt.ylabel("Scaled Value")
plt.title(f"Example Prediction Comparison (batch {idx})")
plt.show()
